# %%
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Citire fisier text

# %%
with open('legislatie/art8.txt', 'r', encoding='utf-8') as file:
  text=file.read()

# %%
text
# Out:
# 'Pentru a fi conduse pe drumurile publice, fiecare autovehicul, tractor agricol sau forestier şi tramvai trebuie să fie dotat cu trusă medicală de prim ajutor, două triunghiuri reflectorizante şi un stingător de incendiu, omologate.'

# %% [markdown]
# ## Tokenize

# %%
nltk.download('punkt_tab')
tokens = word_tokenize(text)
print(tokens)
## Functioneaza bine pe limba romana insa nu este specializat pe aceasta (sintaxe precum 'nu-l' pot fi separate incorect)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Pentru', 'a', 'fi', 'conduse', 'pe', 'drumurile', 'publice', ',', 'fiecare', 'autovehicul', ',', 'tractor', 'agricol', 'sau', 'forestier', 'şi', 'tramvai', 'trebuie', 'să', 'fie', 'dotat', 'cu', 'trusă', 'medicală', 'de', 'prim', 'ajutor', ',', 'două', 'triunghiuri', 'reflectorizante', 'şi', 'un', 'stingător', 'de', 'incendiu', ',', 'omologate', '.']

# %%
word_tokenize('Nu-l vedeam de umbrela')
# Out:
# ['Nu-l', 'vedeam', 'de', 'umbrela']

# %%
# !python -m spacy download ro_core_news_sm
# Out:
# Collecting ro-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ro_core_news_sm-3.8.0/ro_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 84.6 MB/s eta 0:00:00
# Installing collected packages: ro-core-news-sm
# Successfully installed ro-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ro_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("ro_core_news_sm")

doc = nlp(text)
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Pentru', 'a', 'fi', 'conduse', 'pe', 'drumurile', 'publice', ',', 'fiecare', 'autovehicul', ',', 'tractor', 'agricol', 'sau', 'forestier', 'şi', 'tramvai', 'trebuie', 'să', 'fie', 'dotat', 'cu', 'trusă', 'medicală', 'de', 'prim', 'ajutor', ',', 'două', 'triunghiuri', 'reflectorizante', 'şi', 'un', 'stingător', 'de', 'incendiu', ',', 'omologate', '.']

# %%
doc = nlp('Nu-l vedeam de umbrela')
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Nu', '-l', 'vedeam', 'de', 'umbrela']

# %% [markdown]
# ## Eliminare stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words('romanian'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# ['a', 'abia', 'acea', 'aceasta', 'această', 'aceea', 'aceeasi', 'acei', 'aceia', 'acel', 'acela', 'acelasi', 'acele', 'acelea', 'acest', 'acesta', 'aceste', 'acestea', 'acestei', 'acestia', 'acestui', 'aceşti', 'aceştia', 'adica', 'ai', 'aia', 'aibă', 'aici', 'al', 'ala', 'ale', 'alea', 'alt', 'alta', 'altceva', 'altcineva', 'alte', 'altfel', 'alti', 'altii', 'altul', 'am', 'anume', 'apoi', 'ar', 'are', 'as', 'asa', 'asta', 'astea', 'astfel', 'asupra', 'atare', 'atat', 'atata', 'atatea', 'atatia', 'ati', 'atit', 'atita', 'atitea', 'atitia', 'atunci', 'au', 'avea', 'avem', 'aveţi', 'avut', 'aş', 'aţi', 'ba', 'ca', 'cam', 'cand', 'care', 'careia', 'carora', 'caruia', 'cat', 'catre', 'ce', 'cea', 'ceea', 'cei', 'ceilalti', 'cel', 'cele', 'celor', 'ceva', 'chiar', 'ci', 'cind', 'cine', 'cineva', 'cit', 'cita', 'cite', 'citeva', 'citi', 'citiva', 'cu', 'cui', 'cum', 'cumva', 'cât', 'câte', 'câtva', 'câţi', 'cînd', 'cît', 'cîte', 'cîtva', 'cîţi', 'că', 'căci', 'cărei', 'căror', 'cărui', 'către', 'da', 'daca', 'dacă', 'dar', 'dat', 'dată', 'dau', 'de', 'deasupra', 'deci', 'decit', 'deja', 'desi', 'despre', 'deşi', 'din', 'dintr', 'dintr-', 'dintre', 'doar', 'doi', 'doilea', 'două', 'drept', 'dupa', 'după', 'dă', 'e', 'ea', 'ei', 'el', 'ele', 'era', 'eram', 'este', 'eu', 'eşti', 'face', 'fara', 'fata', 'fel', 'fi', 'fie', 'fiecare', 'fii', 'fim', 'fiu', 'fiţi', 'foarte', 'fost', 'fără', 'i', 'ia', 'iar', 'ii', 'il', 'imi', 'in', 'inainte', 'inapoi', 'inca', 'incit', 'insa', 'intr', 'intre', 'isi', 'iti', 'la', 'le', 'li', 'lor', 'lui', 'lângă', 'lîngă', 'm', 'ma', 'mai', 'mea', 'mei', 'mele', 'mereu', 'meu', 'mi', 'mie', 'mine', 'mod', 'mult', 'multa', 'multe', 'multi', 'multă', 'mulţi', 'mâine', 'mîine', 'mă', 'ne', 'ni', 'nici', 'nimeni', 'nimic', 'niste', 'nişte', 'noastre', 'noastră', 'noi', 'nostri', 'nostru', 'nou', 'noua', 'nouă', 'noştri', 'nu', 'numai', 'o', 'or', 'ori', 'oricare', 'orice', 'oricine', 'oricum', 'oricând', 'oricât', 'oricînd', 'oricît', 'oriunde', 'pai', 'parca', 'patra', 'patru', 'pe', 'pentru', 'peste', 'pic', 'pina', 'poate', 'pot', 'prea', 'prima', 'primul', 'prin', 'printr-', 'putini', 'puţin', 'puţina', 'puţină', 'până', 'pînă', 'sa', 'sa-mi', 'sa-ti', 'sai', 'sale', 'sau', 'se', 'si', 'sint', 'sintem', 'spate', 'spre', 'sub', 'sunt', 'suntem', 'sunteţi', 'sus', 'să', 'săi', 'său', 't', 'ta', 'tale', 'te', 'ti', 'tine', 'toata', 'toate', 'toată', 'tocmai', 'tot', 'toti', 'totul', 'totusi', 'totuşi', 'toţi', 'trei', 'treia', 'treilea', 'tu', 'tuturor', 'tăi', 'tău', 'u', 'ul', 'ului', 'un', 'una', 'unde', 'undeva', 'unei', 'uneia', 'unele', 'uneori', 'unii', 'unor', 'unora', 'unu', 'unui', 'unuia', 'unul', 'v', 'va', 'vi', 'voastre', 'voastră', 'voi', 'vom', 'vor', 'vostru', 'vouă', 'voştri', 'vreo', 'vreun', 'vă', 'zi', 'zice', 'îi', 'îl', 'îmi', 'în', 'îţi', 'ăla', 'ălea', 'ăsta', 'ăstea', 'ăştia', 'şi', 'ţi', 'ţie']
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
text
# Out:
# 'Pentru a fi conduse pe drumurile publice, fiecare autovehicul, tractor agricol sau forestier şi tramvai trebuie să fie dotat cu trusă medicală de prim ajutor, două triunghiuri reflectorizante şi un stingător de incendiu, omologate.'

# %%
tokens = word_tokenize(text)

# %%
tokens
# Out:
# ['Pentru',
#  'a',
#  'fi',
#  'conduse',
#  'pe',
#  'drumurile',
#  'publice',
#  ',',
#  'fiecare',
#  'autovehicul',
#  ',',
#  'tractor',
#  'agricol',
#  'sau',
#  'forestier',
#  'şi',
#  'tramvai',
#  'trebuie',
#  'să',
#  'fie',
#  'dotat',
#  'cu',
#  'trusă',
#  'medicală',
#  'de',
#  'prim',
#  'ajutor',
#  ',',
#  'două',
#  'triunghiuri',
#  'reflectorizante',
#  'şi',
#  'un',
#  'stingător',
#  'de',
#  'incendiu',
#  ',',
#  'omologate',
#  '.']

# %%
stop_words_ro = stopwords.words('romanian')

# %%
stop_words_ro
# Out:
# ['a',
#  'abia',
#  'acea',
#  'aceasta',
#  'această',
#  'aceea',
#  'aceeasi',
#  'acei',
#  'aceia',
#  'acel',
#  'acela',
#  'acelasi',
#  'acele',
#  'acelea',
#  'acest',
#  'acesta',
#  'aceste',
#  'acestea',
#  'acestei',
#  'acestia',
#  'acestui',
#  'aceşti',
#  'aceştia',
#  'adica',
#  'ai',
#  'aia',
#  'aibă',
#  'aici',
#  'al',
#  'ala',
#  'ale',
#  'alea',
#  'alt',
#  'alta',
#  'altceva',
#  'altcineva',
#  'alte',
#  'altfel',
#  'alti',
#  'altii',
#  'altul',
#  'am',
#  'anume',
#  'apoi',
#  'ar',
#  'are',
#  'as',
#  'asa',
#  'asta',
#  'astea',
#  'astfel',
#  'asupra',
#  'atare',
#  'atat',
#  'atata',
#  'atatea',
#  'atatia',
#  'ati',
#  'atit',
#  'atita',
#  'atitea',
#  'atitia',
#  'atunci',
#  'au',
#  'avea',
#  'avem',
#  'aveţi',
#  'avut',
#  'aş',
#  'aţi',
#  'ba',
#  'ca',
#  'cam',
#  'cand',
#  'care',
#  'careia',
#  'carora',
#  'caruia',
#  'cat',
#  'catre',
#  'ce',
#  'cea',
#  'ceea',
#  'cei',
#  'ceilalti',
#  'cel',
#  'cele',
#  'celor',
#  'ceva',
#  'chiar',
#  'ci',
#  'cind',
#  'cine',
#  'cineva',
#  'cit',
#  'cita',
#  'cite',
#  'citeva',
#  'citi',
#  'citiva',
#  'cu',
#  'cui',
#  'cum',
#  'cumva',
#  'cât',
#  'câte',
#  'câtva',
#  'câţi',
#  'cînd',
#  'cît',
#  'cîte',
#  'cîtva',
#  'cîţi',
#  'că',
#  'căci',
#  'cărei',
#  'căror',
#  'cărui',
#  'către',
#  'da',
#  'daca',
#  'dacă',
#  'dar',
#  'dat',
#  'dată',
#  'dau',
#  'de',
#  'deasupra',
#  'deci',
#  'decit',
#  'deja',
#  'desi',
#  'despre',
#  'deşi',
#  'din',
#  'dintr',
#  'dintr-',
#  'dintre',
#  'doar',
#  'doi',
#  'doilea',
#  'două',
#  'drept',
#  'dupa',
#  'după',
#  'dă',
#  'e',
#  'ea',
#  'ei',
#  'el',
#  'ele',
#  'era',
#  'eram',
#  'este',
#  'eu',
#  'eşti',
#  'face',
#  'fara',
#  'fata',
#  'fel',
#  'fi',
#  'fie',
#  'fiecare',
#  'fii',
#  'fim',
#  'fiu',
#  'fiţi',
#  'foarte',
#  'fost',
#  'fără',
#  'i',
#  'ia',
#  'iar',
#  'ii',
#  'il',
#  'imi',
#  'in',
#  'inainte',
#  'inapoi',
#  'inca',
#  'incit',
#  'insa',
#  'intr',
#  'intre',
#  'isi',
#  'iti',
#  'la',
#  'le',
#  'li',
#  'lor',
#  'lui',
#  'lângă',
#  'lîngă',
#  'm',
#  'ma',
#  'mai',
#  'mea',
#  'mei',
#  'mele',
#  'mereu',
#  'meu',
#  'mi',
#  'mie',
#  'mine',
#  'mod',
#  'mult',
#  'multa',
#  'multe',
#  'multi',
#  'multă',
#  'mulţi',
#  'mâine',
#  'mîine',
#  'mă',
#  'ne',
#  'ni',
#  'nici',
#  'nimeni',
#  'nimic',
#  'niste',
#  'nişte',
#  'noastre',
#  'noastră',
#  'noi',
#  'nostri',
#  'nostru',
#  'nou',
#  'noua',
#  'nouă',
#  'noştri',
#  'nu',
#  'numai',
#  'o',
#  'or',
#  'ori',
#  'oricare',
#  'orice',
#  'oricine',
#  'oricum',
#  'oricând',
#  'oricât',
#  'oricînd',
#  'oricît',
#  'oriunde',
#  'pai',
#  'parca',
#  'patra',
#  'patru',
#  'pe',
#  'pentru',
#  'peste',
#  'pic',
#  'pina',
#  'poate',
#  'pot',
#  'prea',
#  'prima',
#  'primul',
#  'prin',
#  'printr-',
#  'putini',
#  'puţin',
#  'puţina',
#  'puţină',
#  'până',
#  'pînă',
#  'sa',
#  'sa-mi',
#  'sa-ti',
#  'sai',
#  'sale',
#  'sau',
#  'se',
#  'si',
#  'sint',
#  'sintem',
#  'spate',
#  'spre',
#  'sub',
#  'sunt',
#  'suntem',
#  'sunteţi',
#  'sus',
#  'să',
#  'săi',
#  'său',
#  't',
#  'ta',
#  'tale',
#  'te',
#  'ti',
#  'tine',
#  'toata',
#  'toate',
#  'toată',
#  'tocmai',
#  'tot',
#  'toti',
#  'totul',
#  'totusi',
#  'totuşi',
#  'toţi',
#  'trei',
#  'treia',
#  'treilea',
#  'tu',
#  'tuturor',
#  'tăi',
#  'tău',
#  'u',
#  'ul',
#  'ului',
#  'un',
#  'una',
#  'unde',
#  'undeva',
#  'unei',
#  'uneia',
#  'unele',
#  'uneori',
#  'unii',
#  'unor',
#  'unora',
#  'unu',
#  'unui',
#  'unuia',
#  'unul',
#  'v',
#  'va',
#  'vi',
#  'voastre',
#  'voastră',
#  'voi',
#  'vom',
#  'vor',
#  'vostru',
#  'vouă',
#  'voştri',
#  'vreo',
#  'vreun',
#  'vă',
#  'zi',
#  'zice',
#  'îi',
#  'îl',
#  'îmi',
#  'în',
#  'îţi',
#  'ăla',
#  'ălea',
#  'ăsta',
#  'ăstea',
#  'ăştia',
#  'şi',
#  'ţi',
#  'ţie']

# %%
no_stop_words = [word for word in tokens if word.lower() not in stop_words_ro]

# %%
no_stop_words
# Out:
# ['conduse',
#  'drumurile',
#  'publice',
#  ',',
#  'autovehicul',
#  ',',
#  'tractor',
#  'agricol',
#  'forestier',
#  'tramvai',
#  'trebuie',
#  'dotat',
#  'trusă',
#  'medicală',
#  'prim',
#  'ajutor',
#  ',',
#  'triunghiuri',
#  'reflectorizante',
#  'stingător',
#  'incendiu',
#  ',',
#  'omologate',
#  '.']

# %%
stop_words_ro.extend(['asadar'])

# %%
stop_words_ro
# Out:
# ['a',
#  'abia',
#  'acea',
#  'aceasta',
#  'această',
#  'aceea',
#  'aceeasi',
#  'acei',
#  'aceia',
#  'acel',
#  'acela',
#  'acelasi',
#  'acele',
#  'acelea',
#  'acest',
#  'acesta',
#  'aceste',
#  'acestea',
#  'acestei',
#  'acestia',
#  'acestui',
#  'aceşti',
#  'aceştia',
#  'adica',
#  'ai',
#  'aia',
#  'aibă',
#  'aici',
#  'al',
#  'ala',
#  'ale',
#  'alea',
#  'alt',
#  'alta',
#  'altceva',
#  'altcineva',
#  'alte',
#  'altfel',
#  'alti',
#  'altii',
#  'altul',
#  'am',
#  'anume',
#  'apoi',
#  'ar',
#  'are',
#  'as',
#  'asa',
#  'asta',
#  'astea',
#  'astfel',
#  'asupra',
#  'atare',
#  'atat',
#  'atata',
#  'atatea',
#  'atatia',
#  'ati',
#  'atit',
#  'atita',
#  'atitea',
#  'atitia',
#  'atunci',
#  'au',
#  'avea',
#  'avem',
#  'aveţi',
#  'avut',
#  'aş',
#  'aţi',
#  'ba',
#  'ca',
#  'cam',
#  'cand',
#  'care',
#  'careia',
#  'carora',
#  'caruia',
#  'cat',
#  'catre',
#  'ce',
#  'cea',
#  'ceea',
#  'cei',
#  'ceilalti',
#  'cel',
#  'cele',
#  'celor',
#  'ceva',
#  'chiar',
#  'ci',
#  'cind',
#  'cine',
#  'cineva',
#  'cit',
#  'cita',
#  'cite',
#  'citeva',
#  'citi',
#  'citiva',
#  'cu',
#  'cui',
#  'cum',
#  'cumva',
#  'cât',
#  'câte',
#  'câtva',
#  'câţi',
#  'cînd',
#  'cît',
#  'cîte',
#  'cîtva',
#  'cîţi',
#  'că',
#  'căci',
#  'cărei',
#  'căror',
#  'cărui',
#  'către',
#  'da',
#  'daca',
#  'dacă',
#  'dar',
#  'dat',
#  'dată',
#  'dau',
#  'de',
#  'deasupra',
#  'deci',
#  'decit',
#  'deja',
#  'desi',
#  'despre',
#  'deşi',
#  'din',
#  'dintr',
#  'dintr-',
#  'dintre',
#  'doar',
#  'doi',
#  'doilea',
#  'două',
#  'drept',
#  'dupa',
#  'după',
#  'dă',
#  'e',
#  'ea',
#  'ei',
#  'el',
#  'ele',
#  'era',
#  'eram',
#  'este',
#  'eu',
#  'eşti',
#  'face',
#  'fara',
#  'fata',
#  'fel',
#  'fi',
#  'fie',
#  'fiecare',
#  'fii',
#  'fim',
#  'fiu',
#  'fiţi',
#  'foarte',
#  'fost',
#  'fără',
#  'i',
#  'ia',
#  'iar',
#  'ii',
#  'il',
#  'imi',
#  'in',
#  'inainte',
#  'inapoi',
#  'inca',
#  'incit',
#  'insa',
#  'intr',
#  'intre',
#  'isi',
#  'iti',
#  'la',
#  'le',
#  'li',
#  'lor',
#  'lui',
#  'lângă',
#  'lîngă',
#  'm',
#  'ma',
#  'mai',
#  'mea',
#  'mei',
#  'mele',
#  'mereu',
#  'meu',
#  'mi',
#  'mie',
#  'mine',
#  'mod',
#  'mult',
#  'multa',
#  'multe',
#  'multi',
#  'multă',
#  'mulţi',
#  'mâine',
#  'mîine',
#  'mă',
#  'ne',
#  'ni',
#  'nici',
#  'nimeni',
#  'nimic',
#  'niste',
#  'nişte',
#  'noastre',
#  'noastră',
#  'noi',
#  'nostri',
#  'nostru',
#  'nou',
#  'noua',
#  'nouă',
#  'noştri',
#  'nu',
#  'numai',
#  'o',
#  'or',
#  'ori',
#  'oricare',
#  'orice',
#  'oricine',
#  'oricum',
#  'oricând',
#  'oricât',
#  'oricînd',
#  'oricît',
#  'oriunde',
#  'pai',
#  'parca',
#  'patra',
#  'patru',
#  'pe',
#  'pentru',
#  'peste',
#  'pic',
#  'pina',
#  'poate',
#  'pot',
#  'prea',
#  'prima',
#  'primul',
#  'prin',
#  'printr-',
#  'putini',
#  'puţin',
#  'puţina',
#  'puţină',
#  'până',
#  'pînă',
#  'sa',
#  'sa-mi',
#  'sa-ti',
#  'sai',
#  'sale',
#  'sau',
#  'se',
#  'si',
#  'sint',
#  'sintem',
#  'spate',
#  'spre',
#  'sub',
#  'sunt',
#  'suntem',
#  'sunteţi',
#  'sus',
#  'să',
#  'săi',
#  'său',
#  't',
#  'ta',
#  'tale',
#  'te',
#  'ti',
#  'tine',
#  'toata',
#  'toate',
#  'toată',
#  'tocmai',
#  'tot',
#  'toti',
#  'totul',
#  'totusi',
#  'totuşi',
#  'toţi',
#  'trei',
#  'treia',
#  'treilea',
#  'tu',
#  'tuturor',
#  'tăi',
#  'tău',
#  'u',
#  'ul',
#  'ului',
#  'un',
#  'una',
#  'unde',
#  'undeva',
#  'unei',
#  'uneia',
#  'unele',
#  'uneori',
#  'unii',
#  'unor',
#  'unora',
#  'unu',
#  'unui',
#  'unuia',
#  'unul',
#  'v',
#  'va',
#  'vi',
#  'voastre',
#  'voastră',
#  'voi',
#  'vom',
#  'vor',
#  'vostru',
#  'vouă',
#  'voştri',
#  'vreo',
#  'vreun',
#  'vă',
#  'zi',
#  'zice',
#  'îi',
#  'îl',
#  'îmi',
#  'în',
#  'îţi',
#  'ăla',
#  'ălea',
#  'ăsta',
#  'ăstea',
#  'ăştia',
#  'şi',
#  'ţi',
#  'ţie',
#  'asadar']

# %% [markdown]
# ## Steeming si Lemantizare

# %%
# !pip install simplemma
# Out:
# Collecting simplemma
#   Downloading simplemma-1.2.0-py3-none-any.whl.metadata (24 kB)
# Downloading simplemma-1.2.0-py3-none-any.whl (67.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 12.2 MB/s eta 0:00:00
# Installing collected packages: simplemma
# Successfully installed simplemma-1.2.0

# %%
import simplemma

lemm_text = [simplemma.lemmatize(token, 'ro') for token in no_stop_words]

# %%
print(no_stop_words)
print('-----------------')
print(lemm_text)
## Nu aduce cuvintele la forma de baza in limba romana care nu sunt scrise cu diacritice unde este cazul.
# Out:
# ['conduse', 'drumurile', 'publice', ',', 'autovehicul', ',', 'tractor', 'agricol', 'forestier', 'tramvai', 'trebuie', 'dotat', 'trusă', 'medicală', 'prim', 'ajutor', ',', 'triunghiuri', 'reflectorizante', 'stingător', 'incendiu', ',', 'omologate', '.']
# -----------------
# ['conduce', 'drum', 'publica', ',', 'autovehicul', ',', 'tractor', 'agricol', 'forestier', 'tramvai', 'trebui', 'dota', 'trusă', 'medical', 'prim', 'ajutor', ',', 'triunghi', 'reflectorizante', 'stingător', 'incendiu', ',', 'omologat', '.']

# %% [markdown]
# ## N-Grams

# %%
from nltk.util import ngrams

n = 2
bigrams = list(ngrams(tokens, n))
print(bigrams)
## Folosite in modele probabilistice de limbaj, care estimează probabilitatea unui cuvânt bazată pe cuvintele anterioare.
## Identifica erorile de ortografie sau gramaticale prin compararea secvențelor de cuvinte dintr-un text cu cele dintr-un corpus lingvistic.
## Compararea secvențelor de n-grams din două texte poate fi folosită pentru a măsura similaritatea între ele in aplicatii antiplagiat.
# Out:
# [('Pentru', 'a'), ('a', 'fi'), ('fi', 'conduse'), ('conduse', 'pe'), ('pe', 'drumurile'), ('drumurile', 'publice'), ('publice', ','), (',', 'fiecare'), ('fiecare', 'autovehicul'), ('autovehicul', ','), (',', 'tractor'), ('tractor', 'agricol'), ('agricol', 'sau'), ('sau', 'forestier'), ('forestier', 'şi'), ('şi', 'tramvai'), ('tramvai', 'trebuie'), ('trebuie', 'să'), ('să', 'fie'), ('fie', 'dotat'), ('dotat', 'cu'), ('cu', 'trusă'), ('trusă', 'medicală'), ('medicală', 'de'), ('de', 'prim'), ('prim', 'ajutor'), ('ajutor', ','), (',', 'două'), ('două', 'triunghiuri'), ('triunghiuri', 'reflectorizante'), ('reflectorizante', 'şi'), ('şi', 'un'), ('un', 'stingător'), ('stingător', 'de'), ('de', 'incendiu'), ('incendiu', ','), (',', 'omologate'), ('omologate', '.')]

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

statements = ["Deep learning este un subdomeniu al machine learning.",
              "Inteligenta artificiala si machine learning sunt in stransa legatura una cu alta."
              ]
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(statements)

feature_names = vectorizer.get_feature_names_out()

for doc_index, doc in enumerate(tfidf_matrix):
  print(f"Document: {doc_index + 1}")
  for word_index in doc.nonzero()[1]:
    print(f" {feature_names[word_index]} : {doc[0, word_index]}")
# Out:
# Document: 1
#  deep : 0.36439074431816804
#  learning : 0.5185340314974572
#  este : 0.36439074431816804
#  un : 0.36439074431816804
#  subdomeniu : 0.36439074431816804
#  al : 0.36439074431816804
#  machine : 0.2592670157487286
# Document: 2
#  learning : 0.2144061353375654
#  machine : 0.2144061353375654
#  inteligenta : 0.3013403421812651
#  artificiala : 0.3013403421812651
#  si : 0.3013403421812651
#  sunt : 0.3013403421812651
#  in : 0.3013403421812651
#  stransa : 0.3013403421812651
#  legatura : 0.3013403421812651
#  una : 0.3013403421812651
#  cu : 0.3013403421812651
#  alta : 0.3013403421812651

# %%
tfidf_matrix.toarray()
# Out:
# array([[0.36439074, 0.        , 0.        , 0.        , 0.36439074,
#         0.36439074, 0.        , 0.        , 0.51853403, 0.        ,
#         0.25926702, 0.        , 0.        , 0.36439074, 0.        ,
#         0.36439074, 0.        ],
#        [0.        , 0.30134034, 0.30134034, 0.30134034, 0.        ,
#         0.        , 0.30134034, 0.30134034, 0.21440614, 0.30134034,
#         0.21440614, 0.30134034, 0.30134034, 0.        , 0.30134034,
#         0.        , 0.30134034]])

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 19 stored elements and shape (2, 17)>

# %% [markdown]
# ## Information retrieval

# %%
import os

folder_path = 'legislatie'

documents = []

for filename in os.listdir(folder_path):
  file_path = os.path.join(folder_path, filename)

  with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()
    documents.append(content)

# %%
## Eliminam semnele de punctuatie, indexul de lista, facem toate literele mici, lemantizam
import re

def preprocess_text(text):
  # Transformam textul in litere mici
  text = text.lower()

  # Eliminam capetele de lista
  text = re.sub(r"\(\d+(\.\d+)*\)", "", text)

  # Eliminam stopwords si lemantizam
  doc_tokens = [token.text for token in nlp(text)]
  doc_tokens_no_stop = [word for word in doc_tokens if word not in stop_words_ro]
  text = " ".join([simplemma.lemmatize(token, 'ro') for token in doc_tokens_no_stop])
  ## Elimina de la inceput si de la sfarsit spatiile albe

  ## Eliminam semnele de puctuatie
  text = re.sub(r"[.,!?;:#([{)}]", "", text)

  ## Eliminam caracter linie noua
  text = text.replace('\n', ' ')
  text = re.sub(r"\s+", " ", text).strip()
  ## Strip elimina de la inceput si de la sfarsit spatiile albe
  return text

preprocess_text(documents[0])
# Out:
# 'tramvai troleibuz mopedele tractor agricol forestier altul decât celeprevăzute articol 13 alin inclusiv remorcă destinat tractate vehicul lent precum și vehicul tracțiune animală înregistra nivel primar comună oraș municipiu și sector municipiu București evidență vehicul înregistrat ține autoritate competent prevăzut alin rază care proprietar deținător mandatat sieși domiciliu reședință sediu înscrie dată identificare proprietar și vehicul prevăzut articol 11 alin - registru evidență vehicul înregistrat constitui nivel direcție general permis conducere și înmatriculări înscriere dată realiza intermediu aplicație informatic pune dispoziție autoritate administrație publica local competent gratuit direcție general permis conducere și înmatriculări prelucrare dată registru evidență vehicul înregistrat inclusiv dată caracter personal autoritate și instituție publica atribuție domeniu apărare ordine publica și securitate națională realiza baza protocol încheia între și direcție general permis conducere și înmatriculări'

# %%
documents[0]
# Out:
# '(1) Tramvaiele, troleibuzele, mopedele, tractoarele agricole sau forestiere, altele decât celeprevăzute la art. 13 alin. (3), inclusiv remorcile destinate a fi tractate de acestea, vehiculele lente, precum și vehiculele cu tracțiune animală se înregistrează la nivelul primarilor comunelor, ai orașelor, ai municipiilor și ai sectoarelor municipiului București.\n(2) Evidența vehiculelor înregistrate se ține la autoritatea competentă prevăzută la alin. (1) pe raza căreia proprietarul sau deținătorul mandatat își are domiciliul, reședința sau sediul, care înscrie datele de identificare a proprietarului și a vehiculului prevăzute la art. 11 alin. (11)-(13) în Registrul de evidență a vehiculelor înregistrate, constituit la nivelul Direcției Generale Permise de Conducere și Înmatriculări. Înscrierea datelor se realizează prin intermediul aplicațiilor informatice puse la dispoziția autorităților administrației publice locale competente, în mod gratuit, de către Direcția Generală Permise de Conducere și Înmatriculări.\n(3) Prelucrarea unor date din Registrul de evidență a vehiculelor înregistrate, inclusiv a unor date cu caracter personal, de către autoritățile și instituțiile publice cu atribuții în domeniul apărării, ordinii publice și securității naționale se realizează pe bază de protocol încheiat între acestea și Direcția Generală Permise de Conducere și Înmatriculări.'

# %%
from sklearn.metrics.pairwise import cosine_similarity

question = 'Cu ce trebuie sa fie dotat un automobil pentru a fi condus pe drumuri publice?'
corpus = documents + [question]

processed_corpus = [preprocess_text(context) for context in corpus]
## Se calculeaza vectorii TF-IDF
tfidf_matrix = vectorizer.fit_transform(processed_corpus)

## Calculam similaritatile intre intrebare si fiecare document
question_vector = tfidf_matrix[-1]
scores = cosine_similarity(tfidf_matrix[:-1], question_vector)

## Identificam documentul cel mai relevant
most_relevant_doc_index = scores.argmax()

print(f"Cel mai relevant document: {documents[most_relevant_doc_index]}")
print(f"Relevanta: {scores[most_relevant_doc_index][0]}")
# Out:
# Cel mai relevant document: Pentru a fi conduse pe drumurile publice, fiecare autovehicul, tractor agricol sau forestier şi tramvai trebuie să fie dotat cu trusă medicală de prim ajutor, două triunghiuri reflectorizante şi un stingător de incendiu, omologate.
# Relevanta: 0.35043661921245417

# %% [markdown]
# ## Word embeddings

# %%
documents[0]
# Out:
# '(1) Tramvaiele, troleibuzele, mopedele, tractoarele agricole sau forestiere, altele decât celeprevăzute la art. 13 alin. (3), inclusiv remorcile destinate a fi tractate de acestea, vehiculele lente, precum și vehiculele cu tracțiune animală se înregistrează la nivelul primarilor comunelor, ai orașelor, ai municipiilor și ai sectoarelor municipiului București.\n(2) Evidența vehiculelor înregistrate se ține la autoritatea competentă prevăzută la alin. (1) pe raza căreia proprietarul sau deținătorul mandatat își are domiciliul, reședința sau sediul, care înscrie datele de identificare a proprietarului și a vehiculului prevăzute la art. 11 alin. (11)-(13) în Registrul de evidență a vehiculelor înregistrate, constituit la nivelul Direcției Generale Permise de Conducere și Înmatriculări. Înscrierea datelor se realizează prin intermediul aplicațiilor informatice puse la dispoziția autorităților administrației publice locale competente, în mod gratuit, de către Direcția Generală Permise de Conducere și Înmatriculări.\n(3) Prelucrarea unor date din Registrul de evidență a vehiculelor înregistrate, inclusiv a unor date cu caracter personal, de către autoritățile și instituțiile publice cu atribuții în domeniul apărării, ordinii publice și securității naționale se realizează pe bază de protocol încheiat între acestea și Direcția Generală Permise de Conducere și Înmatriculări.'

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 28.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %% [markdown]
# ## Word2vec

# %%
import re
import numpy as np
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

text = documents[0]
clean = re.sub(r'[^a-zA-ZăâîșțĂÂÎȘȚ\s]', '', text.lower())
sentences = [s.strip().split() for s in clean.split('.') if s.strip()]
print(sentences)

model_w2v = Word2Vec(
    sentences=sentences,
    vector_size=100,     # dimensiunea embedding-ului
    window=5,            # fereastra de context
    min_count=1,         # include toate cuvintele (corpus mic)
    sg=1,                # 1 = Skip-Gram, 0 = CBOW
    epochs=100,          # mai multe epoci pt corpus mic
    seed=42
)

vocab = list(model_w2v.wv.index_to_key)
print(f"\nVocabular: {len(vocab)} cuvinte")

# Vector pentru un cuvânt
sample_word = vocab[0]
vector = model_w2v.wv[sample_word]
print(f"\nVectorul pentru '{sample_word}': shape={vector.shape}")
print(f"  Embedding: {vector.round(4)}")
# Out:
# [['tramvaiele', 'troleibuzele', 'mopedele', 'tractoarele', 'agricole', 'sau', 'forestiere', 'altele', 'decât', 'celeprevăzute', 'la', 'art', 'alin', 'inclusiv', 'remorcile', 'destinate', 'a', 'fi', 'tractate', 'de', 'acestea', 'vehiculele', 'lente', 'precum', 'și', 'vehiculele', 'cu', 'tracțiune', 'animală', 'se', 'înregistrează', 'la', 'nivelul', 'primarilor', 'comunelor', 'ai', 'orașelor', 'ai', 'municipiilor', 'și', 'ai', 'sectoarelor', 'municipiului', 'bucurești', 'evidența', 'vehiculelor', 'înregistrate', 'se', 'ține', 'la', 'autoritatea', 'competentă', 'prevăzută', 'la', 'alin', 'pe', 'raza', 'căreia', 'proprietarul', 'sau', 'deținătorul', 'mandatat', 'își', 'are', 'domiciliul', 'reședința', 'sau', 'sediul', 'care', 'înscrie', 'datele', 'de', 'identificare', 'a', 'proprietarului', 'și', 'a', 'vehiculului', 'prevăzute', 'la', 'art', 'alin', 'în', 'registrul', 'de', 'evidență', 'a', 'vehiculelor', 'înregistrate', 'constituit', 'la', 'nivelul', 'direcției', 'generale', 'permise', 'de', 'conducere', 'și', 'înmatriculări', 'înscrierea', 'datelor', 'se', 'realizează', 'prin', 'intermediul', 'aplicațiilor', 'informatice', 'puse', 'la', 'dispoziția', 'autorităților', 'administrației', 'publice', 'locale', 'competente', 'în', 'mod', 'gratuit', 'de', 'către', 'direcția', 'generală', 'permise', 'de', 'conducere', 'și', 'înmatriculări', 'prelucrarea', 'unor', 'date', 'din', 'registrul', 'de', 'evidență', 'a', 'vehiculelor', 'înregistrate', 'inclusiv', 'a', 'unor', 'date', 'cu', 'caracter', 'personal', 'de', 'către', 'autoritățile', 'și', 'instituțiile', 'publice', 'cu', 'atribuții', 'în', 'domeniul', 'apărării', 'ordinii', 'publice', 'și', 'securității', 'naționale', 'se', 'realizează', 'pe', 'bază', 'de', 'protocol', 'încheiat', 'între', 'acestea', 'și', 'direcția', 'generală', 'permise', 'de', 'conducere', 'și', 'înmatriculări']]
#
# Vocabular: 110 cuvinte
#
# Vectorul pentru 'de': shape=(100,)
#   Embedding: [ 0.0308  0.0425 -0.0607  0.0515 -0.1054  0.0132 -0.0497  0.1486 -0.2645
#   0.0223 -0.2428  0.1555  0.0842  0.166  -0.0722 -0.13    0.0769 -0.2732
#  -0.1028 -0.0727 -0.0579  0.185   0.187   0.1431  0.1482  0.0569 -0.0954
#  -0.0095 -0.1578 -0.1275 -0.1784 -0.0352  0.0691 -0.0481 -0.0433 -0.2097
#   0.0637 -0.1465 -0.0066  0.1584  0.0187 -0.045   0.3207 -0.1194 -0.03
#  -0.0615  0.0772  0.1718  0.2951 -0.0531 -0.0281 -0.2388 -0.086  -0.0731
#   0.1792 -0.1034  0.0627  0.118  -0.0188  0.1483 -0.0164  0.019   0.0075
#   0.0904  0.0255  0.09   -0.0819 -0.1955 -0.1086  0.1167 -0.0779 -0.1178
#   0.0895 -0.1074 -0.0057 -0.1838  0.1081  0.0422 -0.0567 -0.0707  0.0256
#  -0.2006 -0.039   0.034  -0.1121  0.0848 -0.1062 -0.1899 -0.1025  0.0132
#  -0.1447  0.0839  0.0295 -0.1286  0.1192 -0.0418  0.0657  0.0833 -0.0337
#  -0.0755]

# %%
def doc_embedding_w2v(text, model):
    """Media vectorilor Word2Vec pentru toate cuvintele din text."""
    words = re.sub(r'[^a-zA-Z\s]', '', text.lower()).split()
    vecs = [model.wv[w] for w in words if w in model.wv]
    return np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size)

# %%
doc_vec_w2v = doc_embedding_w2v(documents[0], model_w2v)

print("Document embedding cu Word2Vec:")
print(f"  Shape: {doc_vec_w2v.shape}")
print(f"  Embedding: {doc_vec_w2v.round(4)}")
# Out:
# Document embedding cu Word2Vec:
#   Shape: (100,)
#   Embedding: [ 0.0442  0.0328 -0.063   0.059  -0.1032  0.0022 -0.0299  0.1391 -0.2636
#   0.032  -0.2499  0.1363  0.0864  0.1634 -0.0889 -0.1349  0.0858 -0.2757
#  -0.1117 -0.0711 -0.057   0.1908  0.2021  0.1302  0.1436  0.0566 -0.0839
#  -0.0133 -0.1584 -0.1361 -0.1906 -0.034   0.0846 -0.0523 -0.0504 -0.2089
#   0.052  -0.147  -0.0015  0.1519  0.0275 -0.0439  0.3164 -0.1149 -0.0183
#  -0.0745  0.0889  0.1636  0.3033 -0.0638 -0.0318 -0.234  -0.0877 -0.0784
#   0.1939 -0.1096  0.0679  0.1266 -0.0196  0.1522 -0.0197  0.0051  0.0213
#   0.0902  0.0246  0.0958 -0.0968 -0.2041 -0.1005  0.1356 -0.086  -0.126
#   0.0944 -0.1032 -0.0135 -0.1899  0.1249  0.0588 -0.0636 -0.0723  0.0169
#  -0.2173 -0.0308  0.0192 -0.1174  0.0806 -0.0973 -0.1882 -0.1101  0.0024
#  -0.1466  0.078   0.0276 -0.136   0.1068 -0.0414  0.0783  0.0807 -0.0351
#  -0.0715]
